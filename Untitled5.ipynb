# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanshidha/AI_Datascience/blob/master/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df.head()
# Out:
#                            Indicator PUBLISH STATES  Year  ... Low High Comments
# 0   Life expectancy at birth (years)      Published  1990  ... NaN  NaN      NaN
# 1   Life expectancy at birth (years)      Published  2000  ... NaN  NaN      NaN
# 2  Life expectancy at age 60 (years)      Published  2012  ... NaN  NaN      NaN
# 3  Life expectancy at age 60 (years)      Published  2000  ... NaN  NaN      NaN
# 4   Life expectancy at birth (years)      Published  2012  ... NaN  NaN      NaN
#
# [5 rows x 12 columns]

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
df1.head()
# Out:
#              STATION         STATION_NAME      DATE  ...  WT08  WT18  WT03
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101  ... -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102  ... -9999 -9999 -9999
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103  ... -9999 -9999 -9999
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105  ... -9999 -9999 -9999
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106  ... -9999 -9999 -9999
#
# [5 rows x 21 columns]

# %%
#1.Get the Metadata from the above files.
print("Metadata for data-text") 
df.info()
print("------------------------------------------------------------------------------------------------------------")
print("Metadata for berlin_weather_oldest ")  
df1.info()
# Out:
# Metadata for data-text
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Indicator                4656 non-null   object
#  1   PUBLISH STATES           4656 non-null   object
#  2   Year                     4656 non-null   int64
#  3   WHO region               4656 non-null   object
#  4   World Bank income group  4656 non-null   object
#  5   Country                  4656 non-null   object
#  6   Sex                      4656 non-null   object
#  7   Display Value            4656 non-null   int64
#  8   Numeric                  4656 non-null   float64
#  9   Low                      0 non-null      float64
#  10  High                     0 non-null      float64
#  11  Comments                 0 non-null      float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB
# ...

# %%
#2.Get the row names from the above files.

print("row name for first dataset :")
df.index.values
# Out:
# row name for first dataset :
# array([   0,    1,    2, ..., 4653, 4654, 4655])

# %%
print("row name for second dataset :")
df1.index.values
# Out:
# row name for second dataset :
# array([     0,      1,      2, ..., 117205, 117206, 117207])

# %%
#3.Change the column name from any of the above file and store the changes made permanently
df.rename(columns={"Country":"country"},inplace=True)   
df.head()
# Out:
#                            Indicator PUBLISH STATES  Year  ... Low High Comments
# 0   Life expectancy at birth (years)      Published  1990  ... NaN  NaN      NaN
# 1   Life expectancy at birth (years)      Published  2000  ... NaN  NaN      NaN
# 2  Life expectancy at age 60 (years)      Published  2012  ... NaN  NaN      NaN
# 3  Life expectancy at age 60 (years)      Published  2000  ... NaN  NaN      NaN
# 4   Life expectancy at birth (years)      Published  2012  ... NaN  NaN      NaN
#
# [5 rows x 12 columns]

# %%
df1.rename(columns={"STATION":"station"},inplace=True)                  
df1.head()
# Out:
#              station         STATION_NAME      DATE  ...  WT08  WT18  WT03
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101  ... -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102  ... -9999 -9999 -9999
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103  ... -9999 -9999 -9999
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105  ... -9999 -9999 -9999
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106  ... -9999 -9999 -9999
#
# [5 rows x 21 columns]

# %%
#4.Change the names of multiple columns
df.rename(columns={"Year":"YEAR","Sex":"SEX"},inplace=True) 
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  YEAR  ... Low High Comments
# 0  Life expectancy at birth (years)      Published  1990  ... NaN  NaN      NaN
# 1  Life expectancy at birth (years)      Published  2000  ... NaN  NaN      NaN
#
# [2 rows x 12 columns]

# %%
#5.Arrange values of a particular column in ascending order
df.sort_values('Numeric').head()
# Out:
#                               Indicator PUBLISH STATES  ...  High Comments
# 265   Life expectancy at age 60 (years)      Published  ...   NaN      NaN
# 1476  Life expectancy at age 60 (years)      Published  ...   NaN      NaN
# 1474  Life expectancy at age 60 (years)      Published  ...   NaN      NaN
# 3070  Life expectancy at age 60 (years)      Published  ...   NaN      NaN
# 3072  Life expectancy at age 60 (years)      Published  ...   NaN      NaN
#
# [5 rows x 12 columns]

# %%
#6.Arrange multiple column values in ascending order.
df[0:5].sort_values(['YEAR','Indicator','WHO region']).head()
# Out:
#                            Indicator PUBLISH STATES  YEAR  ... Low High Comments
# 0   Life expectancy at birth (years)      Published  1990  ... NaN  NaN      NaN
# 3  Life expectancy at age 60 (years)      Published  2000  ... NaN  NaN      NaN
# 1   Life expectancy at birth (years)      Published  2000  ... NaN  NaN      NaN
# 2  Life expectancy at age 60 (years)      Published  2012  ... NaN  NaN      NaN
# 4   Life expectancy at birth (years)      Published  2012  ... NaN  NaN      NaN
#
# [5 rows x 12 columns]

# %%
#7.Make country as the first column of the dataframe
df.set_index('country').head()
# Out:
#                                               Indicator  ... Comments
# country                                                  ...
# Andorra                Life expectancy at birth (years)  ...      NaN
# Andorra                Life expectancy at birth (years)  ...      NaN
# Andorra               Life expectancy at age 60 (years)  ...      NaN
# Andorra               Life expectancy at age 60 (years)  ...      NaN
# United Arab Emirates   Life expectancy at birth (years)  ...      NaN
#
# [5 rows x 11 columns]

# %%
#8.Get the column array using a variable
import numpy as np
np.array(df[['Numeric']],dtype=np.int)
# Out:
# array([[77],
#        [80],
#        [28],
#        ...,
#        [49],
#        [36],
#        [51]])

# %%
#9.Get the subset rows 11, 24, 37
df.loc[[11,24,37]]
# Out:
#                             Indicator PUBLISH STATES  YEAR  ... Low High Comments
# 11   Life expectancy at birth (years)      Published  2012  ... NaN  NaN      NaN
# 24  Life expectancy at age 60 (years)      Published  2012  ... NaN  NaN      NaN
# 37  Life expectancy at age 60 (years)      Published  2012  ... NaN  NaN      NaN
#
# [3 rows x 12 columns]

# %%
#10.Get the subset rows excluding 5, 12, 23, and 56
df.drop([5,12,23,56])[0:57]
# Out:
#                             Indicator PUBLISH STATES  YEAR  ... Low High Comments
# 0    Life expectancy at birth (years)      Published  1990  ... NaN  NaN      NaN
# 1    Life expectancy at birth (years)      Published  2000  ... NaN  NaN      NaN
# 2   Life expectancy at age 60 (years)      Published  2012  ... NaN  NaN      NaN
# 3   Life expectancy at age 60 (years)      Published  2000  ... NaN  NaN      NaN
# 4    Life expectancy at birth (years)      Published  2012  ... NaN  NaN      NaN
# 6   Life expectancy at age 60 (years)      Published  1990  ... NaN  NaN      NaN
# 7   Life expectancy at age 60 (years)      Published  2012  ... NaN  NaN      NaN
# 8    Life expectancy at birth (years)      Published  2012  ... NaN  NaN      NaN
# 9    Life expectancy at birth (years)      Published  2000  ... NaN  NaN      NaN
# 10   Life expectancy at birth (years)      Published  2012  ... NaN  NaN      NaN
# ...

# %%
#11.find rows with NaN values
df.isnull()
# Out:
#       Indicator  PUBLISH STATES   YEAR  ...   Low  High  Comments
# 0         False           False  False  ...  True  True      True
# 1         False           False  False  ...  True  True      True
# 2         False           False  False  ...  True  True      True
# 3         False           False  False  ...  True  True      True
# 4         False           False  False  ...  True  True      True
# ...         ...             ...    ...  ...   ...   ...       ...
# 4651      False           False  False  ...  True  True      True
# 4652      False           False  False  ...  True  True      True
# 4653      False           False  False  ...  True  True      True
# 4654      False           False  False  ...  True  True      True
# 4655      False           False  False  ...  True  True      True
#
# [4656 rows x 12 columns]

# %%
#12.show rows from dataset 1 country = india with high income
a=df[df['country']=='India']
a
# Out:
#                                             Indicator  ... Comments
# 372                  Life expectancy at birth (years)  ...      NaN
# 373                  Life expectancy at birth (years)  ...      NaN
# 750                  Life expectancy at birth (years)  ...      NaN
# 751                  Life expectancy at birth (years)  ...      NaN
# 752                 Life expectancy at age 60 (years)  ...      NaN
# 753                 Life expectancy at age 60 (years)  ...      NaN
# 754                 Life expectancy at age 60 (years)  ...      NaN
# 1152                 Life expectancy at birth (years)  ...      NaN
# 1153                 Life expectancy at birth (years)  ...      NaN
# 1154                 Life expectancy at birth (years)  ...      NaN
# 1155                Life expectancy at age 60 (years)  ...      NaN
# 1156                Life expectancy at age 60 (years)  ...      NaN
# 1157                Life expectancy at age 60 (years)  ...      NaN
# ...

# %%
try:
    df[df['country']=='India'] & df[df['World Bank income group']=='High-income']
except:
    df[df['country']=='India'].max()

# %%
df[df['country']=='India'].max()
# Out:
# Indicator                  Life expectancy at birth (years)
# PUBLISH STATES                                    Published
# YEAR                                                   2012
# WHO region                                  South-East Asia
# World Bank income group                 Lower-middle-income
# country                                               India
# SEX                                                    Male
# Display Value                                            68
# Numeric                                                  68
# Low                                                     NaN
# High                                                    NaN
# Comments                                                NaN
# dtype: object
